# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Comentario de Revisor </b> <a class="tocSkip"></a>
#
# Hola Pablo, ¿cómo va todo? Espero que estés teniendo una buena jornada.
#
# El archivo enviado anteriormente no puede ser leído, al parecer no tiene el formato de jupyter notebook y viene vacío. Por favor, envía nuevamente tu notebook.
#
#
#
# Saludos!
#
#
#
# </div>
