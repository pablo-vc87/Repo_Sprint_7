# %% [markdown]
# # Series Temporales

# %% [markdown]
# ## Análisis de series temporales

# %% [markdown]
# ### Series temporales (5 ejercicios)
#
# 1) Cambia el tipo de datos de los datos de Datetime de object a datetime64. Pero primero, ejecuta el código y verifica la información general sobre los datos.
#
# Selecciona cualquier método de conversión de datos de la documentación de pandas. No es necesario especificar el formato de salida de la fecha, porque la librería lo determinará de forma automática.
#
# Muestra en la pantalla la información sobre la tabla (en precódigo).

# %% [markdown]
# ### Remuestreo (2)

# %% [markdown]
# ### Media móvil

# %% [markdown]
# ### Tendencias y estacionalidad (2)

# %% [markdown]
# ### Diferencias de series temporales (1)

# %% [markdown]
# ## Pronóstico de series temporales (1)

# %% [markdown]
# ### Exactitud del pronóstico (2)

# %% [markdown]
# ### Creación de características (3)

# %% [markdown]
# ### Entrenamiento del modelo (2)

# %% [markdown]
# # Proyecto
